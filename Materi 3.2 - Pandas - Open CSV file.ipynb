# %% [markdown]
# # OPEN CSV FILE

# %% [markdown]
# ## Data set Library: will be using data of Uber 2016
# The data can be obtained from kaggle: https://www.kaggle.com/datasets

# %%
import pandas as pd

# %%
# if file is .txt and .csv open with pd.read_csv function
# if file is excel open with pd.read_xlsx

data = pd.read_csv("My Uber Drives - 2016.csv")
data
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 0       1/1/2016 21:11    1/1/2016 21:17  Business       Fort Pierce
# 1        1/2/2016 1:25     1/2/2016 1:37  Business       Fort Pierce
# 2       1/2/2016 20:25    1/2/2016 20:38  Business       Fort Pierce
# 3       1/5/2016 17:31    1/5/2016 17:45  Business       Fort Pierce
# 4       1/6/2016 14:42    1/6/2016 15:49  Business       Fort Pierce
# ...                ...               ...       ...               ...
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals               NaN       NaN               NaN
#
#                  STOP*   MILES*         PURPOSE*
# 0          Fort Pierce      5.1   Meal/Entertain
# ...

# %% [markdown]
# ## Basic Operation

# %%
data.head()
# Out:
#       START_DATE*       END_DATE* CATEGORY*       START*            STOP*  \
# 0  1/1/2016 21:11  1/1/2016 21:17  Business  Fort Pierce      Fort Pierce
# 1   1/2/2016 1:25   1/2/2016 1:37  Business  Fort Pierce      Fort Pierce
# 2  1/2/2016 20:25  1/2/2016 20:38  Business  Fort Pierce      Fort Pierce
# 3  1/5/2016 17:31  1/5/2016 17:45  Business  Fort Pierce      Fort Pierce
# 4  1/6/2016 14:42  1/6/2016 15:49  Business  Fort Pierce  West Palm Beach
#
#    MILES*         PURPOSE*
# 0     5.1   Meal/Entertain
# 1     5.0              NaN
# 2     4.8  Errand/Supplies
# 3     4.7          Meeting
# 4    63.7   Customer Visit

# %%
data.tail()
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals               NaN       NaN               NaN
#
#                  STOP*   MILES*        PURPOSE*
# 1151  Unknown Location      3.9  Temporary Site
# 1152  Unknown Location     16.2         Meeting
# 1153           Gampaha      6.4  Temporary Site
# 1154         Ilukwatta     48.2  Temporary Site
# 1155               NaN  12204.7             NaN

# %%
data.shape
# Out:
# (1156, 7)

# %%
data.dtypes
# Out:
# START_DATE*     object
# END_DATE*       object
# CATEGORY*       object
# START*          object
# STOP*           object
# MILES*         float64
# PURPOSE*        object
# dtype: object

# %% [markdown]
# ### Convert Data Types

# %% [markdown]
# It can be seen that the __START_DATE*__ and __END_DATE*__ is object type data. While in fact, it is a _date_

# %%
data1 = pd.DataFrame({'cost':["5","5","7"],
                      "Amount":[11,12,13],
                      "Date": ["11-10-2020","12-10-2020","13-10-2020"]})
data1
# Out:
#   cost  Amount        Date
# 0    5      11  11-10-2020
# 1    5      12  12-10-2020
# 2    7      13  13-10-2020

# %%
data1.dtypes
# Out:
# cost      object
# Amount     int64
# Date      object
# dtype: object

# %%
data1['Date']=pd.to_datetime(data1['Date']) # to_datetime untuk merubah tipe tanggal dari object menjadi datetime64[ns]
data1.dtypes
# Out:
# cost              object
# Amount             int64
# Date      datetime64[ns]
# dtype: object

# %%
data1
# Out:
#   cost  Amount       Date
# 0    5      11 2020-11-10
# 1    5      12 2020-12-10
# 2    7      13 2020-10-13

# %%
data1['cost'] = pd.to_numeric(data1['cost']) # to_numeric : merubah data cost yg sblmnya ber tipe 'object64' menjadi (int64)
data1.dtypes
# Out:
# cost               int64
# Amount             int64
# Date      datetime64[ns]
# dtype: object

# %% [markdown]
#  ### Apply to our DataFrame

# %%
data
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 0       1/1/2016 21:11    1/1/2016 21:17  Business       Fort Pierce
# 1        1/2/2016 1:25     1/2/2016 1:37  Business       Fort Pierce
# 2       1/2/2016 20:25    1/2/2016 20:38  Business       Fort Pierce
# 3       1/5/2016 17:31    1/5/2016 17:45  Business       Fort Pierce
# 4       1/6/2016 14:42    1/6/2016 15:49  Business       Fort Pierce
# ...                ...               ...       ...               ...
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals               NaN       NaN               NaN
#
#                  STOP*   MILES*         PURPOSE*
# 0          Fort Pierce      5.1   Meal/Entertain
# ...

# %%
data.dtypes # seharusnya START_DATE & END_DATE berbentuk datetime bukan object
# Out:
# START_DATE*     object
# END_DATE*       object
# CATEGORY*       object
# START*          object
# STOP*           object
# MILES*         float64
# PURPOSE*        object
# dtype: object

# %%
data["START_DATE*"] = pd.to_datetime(data["START_DATE*"],format='%m/%d/%Y %H:%M')


#error tersebut muncul karena pada data set ada 'totals' pada kolom START_DATE, sehingga system tdk dapat merubah 
#jadi harus menggunakan format 'coerce', yg akan merubah kolom 'totals' menjadi NAT
# errors: 'str' = 'raise',
#- If 'coerce', then invalid parsing will be set as NaT.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py in _to_datetime_with_format(arg, orig_arg, name, tz, fmt, exact, errors, infer_datetime_format)
#     508         try:
# --> 509             values, tz = conversion.datetime_to_datetime64(arg)
#     510             dta = DatetimeArray(values, dtype=tz_to_dtype(tz))
#
# ~\anaconda3\lib\site-packages\pandas\_libs\tslibs\conversion.pyx in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1200/340364321.py in <module>
# ----> 1 data["START_DATE*"] = pd.to_datetime(data["START_DATE*"],format='%m/%d/%Y %H:%M')
#       2
# ...

# %%
data["START_DATE*"] = pd.to_datetime(data["START_DATE*"],format='%m/%d/%Y %H:%M', errors = 'coerce')
data.dtypes
# Out:
# START_DATE*    datetime64[ns]
# END_DATE*              object
# CATEGORY*              object
# START*                 object
# STOP*                  object
# MILES*                float64
# PURPOSE*               object
# dtype: object

# %%
data # terlihat total di kolom START_DATE berubah menjadi NAT
# Out:
#              START_DATE*         END_DATE* CATEGORY*            START*  \
# 0    2016-01-01 21:11:00    1/1/2016 21:17  Business       Fort Pierce
# 1    2016-01-02 01:25:00     1/2/2016 1:37  Business       Fort Pierce
# 2    2016-01-02 20:25:00    1/2/2016 20:38  Business       Fort Pierce
# 3    2016-01-05 17:31:00    1/5/2016 17:45  Business       Fort Pierce
# 4    2016-01-06 14:42:00    1/6/2016 15:49  Business       Fort Pierce
# ...                  ...               ...       ...               ...
# 1151 2016-12-31 13:24:00  12/31/2016 13:42  Business           Kar?chi
# 1152 2016-12-31 15:03:00  12/31/2016 15:38  Business  Unknown Location
# 1153 2016-12-31 21:32:00  12/31/2016 21:50  Business        Katunayake
# 1154 2016-12-31 22:08:00  12/31/2016 23:51  Business           Gampaha
# 1155                 NaT               NaN       NaN               NaN
#
#                  STOP*   MILES*         PURPOSE*
# 0          Fort Pierce      5.1   Meal/Entertain
# ...

# %%
#convert data to datetime format

pd.to_datetime(data.loc[:1154, 'START_DATE*'], format='%m/%d/%Y %H:%M')
# Out:
# 0      2016-01-01 21:11:00
# 1      2016-01-02 01:25:00
# 2      2016-01-02 20:25:00
# 3      2016-01-05 17:31:00
# 4      2016-01-06 14:42:00
#                ...
# 1150   2016-12-31 01:07:00
# 1151   2016-12-31 13:24:00
# 1152   2016-12-31 15:03:00
# 1153   2016-12-31 21:32:00
# 1154   2016-12-31 22:08:00
# Name: START_DATE*, Length: 1155, dtype: datetime64[ns]

# %%
pd.to_datetime(data.iloc[:1154, 0], format='%m/%d/%Y %H:%M')
# Out:
# 0      2016-01-01 21:11:00
# 1      2016-01-02 01:25:00
# 2      2016-01-02 20:25:00
# 3      2016-01-05 17:31:00
# 4      2016-01-06 14:42:00
#                ...
# 1149   2016-12-30 23:06:00
# 1150   2016-12-31 01:07:00
# 1151   2016-12-31 13:24:00
# 1152   2016-12-31 15:03:00
# 1153   2016-12-31 21:32:00
# Name: START_DATE*, Length: 1154, dtype: datetime64[ns]

# %%
data.dtypes
# Out:
# START_DATE*    datetime64[ns]
# END_DATE*              object
# CATEGORY*              object
# START*                 object
# STOP*                  object
# MILES*                float64
# PURPOSE*               object
# dtype: object

# %%
data["END_DATE*"] = pd.to_datetime(data["START_DATE*"],format='%m/%d/%Y %H:%M', errors = 'coerce')
data
# Out:
#              START_DATE*           END_DATE* CATEGORY*            START*  \
# 0    2016-01-01 21:11:00 2016-01-01 21:11:00  Business       Fort Pierce
# 1    2016-01-02 01:25:00 2016-01-02 01:25:00  Business       Fort Pierce
# 2    2016-01-02 20:25:00 2016-01-02 20:25:00  Business       Fort Pierce
# 3    2016-01-05 17:31:00 2016-01-05 17:31:00  Business       Fort Pierce
# 4    2016-01-06 14:42:00 2016-01-06 14:42:00  Business       Fort Pierce
# ...                  ...                 ...       ...               ...
# 1151 2016-12-31 13:24:00 2016-12-31 13:24:00  Business           Kar?chi
# 1152 2016-12-31 15:03:00 2016-12-31 15:03:00  Business  Unknown Location
# 1153 2016-12-31 21:32:00 2016-12-31 21:32:00  Business        Katunayake
# 1154 2016-12-31 22:08:00 2016-12-31 22:08:00  Business           Gampaha
# 1155                 NaT                 NaT       NaN               NaN
#
#                  STOP*   MILES*         PURPOSE*
# ...

# %%
data.dtypes
# Out:
# START_DATE*    datetime64[ns]
# END_DATE*      datetime64[ns]
# CATEGORY*              object
# START*                 object
# STOP*                  object
# MILES*                float64
# PURPOSE*               object
# dtype: object

# %% [markdown]
# ## Data Set Summarization

# %%
# Melakukan pendeskripsian atas data yang bersifat numeric

data.describe()

#count: Banyaknya data pada data set
#mean: rata2 dari data set
# Out:
#              MILES*
# count   1156.000000
# mean      21.115398
# std      359.299007
# min        0.500000
# 25%        2.900000
# 50%        6.000000
# 75%       10.400000
# max    12204.700000

# %%
# Jika ingin menampilkan keseluruhan data yg ada di data set 
# yang tidak bisa di tampilkan nilainya dari data set tersebut akan di tunjukan dalam bentuk NaN 
data.describe(include = 'all')
# Out:
# C:\Users\raris\AppData\Local\Temp/ipykernel_1200/2667138952.py:3: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   data.describe(include = 'all')
#                 START_DATE*        END_DATE* CATEGORY* START* STOP*  \
# count                  1155             1155      1155   1155  1155
# unique                 1154             1154         2    177   188
# top     2016-06-28 23:34:00  6/28/2016 23:59  Business   Cary  Cary
# freq                      2                2      1078    201   203
# first   2016-01-01 21:11:00              NaN       NaN    NaN   NaN
# last    2016-12-31 22:08:00              NaN       NaN    NaN   NaN
# mean                    NaN              NaN       NaN    NaN   NaN
# std                     NaN              NaN       NaN    NaN   NaN
# ...

# %%
#lebih bagus dalam menampilkan data karena dapat menampilkan data /total entries (jumlah data), total index, jumlah kolom dll

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1156 entries, 0 to 1155
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   START_DATE*  1155 non-null   datetime64[ns]
#  1   END_DATE*    1155 non-null   object
#  2   CATEGORY*    1155 non-null   object
#  3   START*       1155 non-null   object
#  4   STOP*        1155 non-null   object
#  5   MILES*       1156 non-null   float64
#  6   PURPOSE*     653 non-null    object
# dtypes: datetime64[ns](1), float64(1), object(5)
# memory usage: 63.3+ KB

# %%
# count of unique start locations
data["START*"].value_counts()
# Out:
# Cary                201
# Unknown Location    148
# Morrisville          85
# Whitebridge          68
# Islamabad            57
#                    ...
# Florence              1
# Ridgeland             1
# Daytona Beach         1
# Sky Lake              1
# Gampaha               1
# Name: START*, Length: 177, dtype: int64
