# %% [markdown]
# ### Anatomy of Figures

# %% [markdown]
# ![anatomy%20of%20figure.jpg](attachment:anatomy%20of%20figure.jpg)

# %% [markdown]
# ### Chart_Suggestions

# %% [markdown]
# ![chart_suggestion.jpg](attachment:chart_suggestion.jpg)

# %% [markdown]
# ### Charts 1
#
# ![chart1.jpg](attachment:chart1.jpg)

# %% [markdown]
# ### Charts 2
#
#
# ![chart2.jpg](attachment:chart2.jpg)

# %% [markdown]
# ### Format Strings
#
# fmt = '[marker][line][color]'
# ![image.png](attachment:image.png)

# %% [markdown]
# ![Format_strings.png](attachment:Format_strings.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Refference :
#
# www.matplotlib.org/cheatsheets/cheatsheets.pdf ;
#
# www.matplotlib.org
#
# Reff kode hex untuk warna: www.colorhunt.co
