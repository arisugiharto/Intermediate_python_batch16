# %% [markdown]
# # ASSIGNMENT

# %% [markdown]
# 1. Create a 5x5 matrix with values ranging from 3 to 7.\ ![image.png](attachment:image.png)

# %%
import numpy as np
from numpy import random

# %%
x = np.array ([[3,4,5,6,7],
              [3,4,5,6,7],
              [3,4,5,6,7],
              [3,4,5,6,7],
              [3,4,5,6,7]])
x
# Out:
# array([[3, 4, 5, 6, 7],
#        [3, 4, 5, 6, 7],
#        [3, 4, 5, 6, 7],
#        [3, 4, 5, 6, 7],
#        [3, 4, 5, 6, 7]])

# %% [markdown]
# 2. Create an array with shape of 4x4 and turn it into two arrays along the second axis.\

# %%
import numpy as np

# %%
arr2 = random.randint(1, 5, size=(4,4))
arr2
# Out:
# array([[1, 1, 1, 1],
#        [1, 3, 4, 4],
#        [4, 4, 3, 1],
#        [3, 1, 1, 2]])

# %%
arr4 = arr2.reshape(2,8)
arr4s
# Out:
# array([[1, 1, 1, 1, 1, 3, 4, 4],
#        [4, 4, 3, 1, 3, 1, 1, 2]])
