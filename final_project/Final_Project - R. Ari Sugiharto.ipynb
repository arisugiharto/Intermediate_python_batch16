# %% [markdown]
# # Final Project

# %% [markdown]
# __`Deskripsi`__ :
# - Pernahkah kamu bertanya kapan waktu terbaik untuk memesan kamar hotel?
# - Atau berapa lama waktu tinggal untuk mendapatkan harga dengan rate terbaik?
# - Bagaimana jika kamu ingin memprediksi kapan hotel mendapat pesanan unik?

# %% [markdown]
# __`Konten`__ :
#
# - Data mengandung informasi pemesanan hotel dan resort.
# - Informasi yang terkandung meliputi kapan waktu pemesanan, durasi stay, jumlah orang dewasa, anak, dan/atau bayi, jumlah tempat parker yang tersedia, dan lain-lain.
# - Semua informasi personal terkait pemesan telah dihapus dari data.

# %% [markdown]
# ## Tugas:

# %% [markdown]
# 1. Jelaskan apa gambaran besar yang anda dapatkan dari data tersebut.
# 2. Tunjukkan properties dari data pada setiap kolom, seperti type, missing value, dan lain-lain.
# 3. Tunjukkan jumlah data, mean, median, dan standar deviasi.
# 4. Berapa nilai minimal dan maksimal untuk kolom yang mengandung data numerik?
# 5.	Selesaikan masalah missing value dengan cara berikut:
#     - Drop kolom-kolom yang mengandung missing value lebih dari 50% keseluruhan data.
#     - Isi missing value pada kolom country dan children dengan data yang paling banyak muncul.
#     - Isi missing value pada kolom agent dengan mean.
# 6.	Buat kategori berdasarkan lead time: Short, Medium, dan Long
# 7.	Filter semua data yang memiliki reservation_status_date di > 2017
# 8.	Visualisasikan arrival_date_month  untuk melihat bulan dimana pengunjung terbanyak

# %%
import pandas as pd
import numpy as np
from numpy import random
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("hotel_bookings.csv")
df
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %% [markdown]
# 1. Jelaskan apa gambaran besar yang anda dapatkan dari data tersebut.

# %% [markdown]
# ### Jawaban No. 1:
#
# Data di atas merupakan summary dari data penginapan/hotel yg terdiri dari:
# - Jenis hotel
# - Negara
# - Tgl, bln, tahun kedatangan
# - Total menginap (hari) di weekend
# - Tamu yang datang (Dewasa, anak, infants)

# %% [markdown]
# 2. Tunjukkan properties dari data pada setiap kolom, seperti type, missing value, dan lain-lain.

# %% [markdown]
# ### Jawaban No. 2:

# %%
df.isnull().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
df.dtypes
# Out:
# hotel                              object
# is_canceled                         int64
# lead_time                           int64
# arrival_date_year                   int64
# arrival_date_month                 object
# arrival_date_week_number            int64
# arrival_date_day_of_month           int64
# stays_in_weekend_nights             int64
# stays_in_week_nights                int64
# adults                              int64
# children                          float64
# babies                              int64
# meal                               object
# country                            object
# market_segment                     object
# distribution_channel               object
# is_repeated_guest                   int64
# previous_cancellations              int64
# previous_bookings_not_canceled      int64
# reserved_room_type                 object
# assigned_room_type                 object
# booking_changes                     int64
# ...

# %% [markdown]
# 3. Tunjukkan jumlah data, mean, median, dan standar deviasi.

# %% [markdown]
# ### Jawaban No. 3 :

# %%
df.describe().T
# Out:
#                                    count         mean         std      min  \
# is_canceled                     119390.0     0.370416    0.482918     0.00
# lead_time                       119390.0   104.011416  106.863097     0.00
# arrival_date_year               119390.0  2016.156554    0.707476  2015.00
# arrival_date_week_number        119390.0    27.165173   13.605138     1.00
# arrival_date_day_of_month       119390.0    15.798241    8.780829     1.00
# stays_in_weekend_nights         119390.0     0.927599    0.998613     0.00
# stays_in_week_nights            119390.0     2.500302    1.908286     0.00
# adults                          119390.0     1.856403    0.579261     0.00
# children                        119386.0     0.103890    0.398561     0.00
# babies                          119390.0     0.007949    0.097436     0.00
# is_repeated_guest               119390.0     0.031912    0.175767     0.00
# ...

# %% [markdown]
# 4. Berapa nilai minimal dan maksimal untuk kolom yang mengandung data numerik?

# %% [markdown]
# ## Jawaban No. 4

# %%
df4=df
df4
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 34 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
df.describe().T
# Out:
#                                    count         mean         std      min  \
# is_canceled                     119390.0     0.370416    0.482918     0.00
# lead_time                       119390.0   104.011416  106.863097     0.00
# arrival_date_year               119390.0  2016.156554    0.707476  2015.00
# arrival_date_week_number        119390.0    27.165173   13.605138     1.00
# arrival_date_day_of_month       119390.0    15.798241    8.780829     1.00
# stays_in_weekend_nights         119390.0     0.927599    0.998613     0.00
# stays_in_week_nights            119390.0     2.500302    1.908286     0.00
# adults                          119390.0     1.856403    0.579261     0.00
# children                        119386.0     0.103890    0.398561     0.00
# babies                          119390.0     0.007949    0.097436     0.00
# is_repeated_guest               119390.0     0.031912    0.175767     0.00
# ...

# %% [markdown]
# #### Minimum Value

# %% [markdown]
# #### Maximum value

# %%
numerics = [int64,float64]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10192/2283970461.py in <module>
# ----> 1 df4.describe("max")
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in describe(self, percentiles, include, exclude, datetime_is_numeric)
#   10022         max            NaN      3.0
#   10023         """
# > 10024         return describe_ndframe(
#   10025             obj=self,
#   10026             include=include,
#
# ~\anaconda3\lib\site-packages\pandas\core\describe.py in describe_ndframe(obj, include, exclude, datetime_is_numeric, percentiles)
#      77     Dataframe or series description.
#      78     """
# ---> 79     percentiles = refine_percentiles(percentiles)
#      80
#      81     describer: NDFrameDescriberAbstract
#
# ~\anaconda3\lib\site-packages\pandas\core\describe.py in refine_percentiles(percentiles)
#     406
# ...

# %% [markdown]
# 5. Selesaikan masalah missing value dengan cara berikut:
#     - Drop kolom-kolom yang mengandung missing value lebih dari 50% keseluruhan data.
#     - Isi missing value pada kolom country dan children dengan data yang paling banyak muncul.
#     - isi missing value pada kolom agent dengan mean.

# %% [markdown]
# ### Jawaban No. 5

# %%
df5=df
df5
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
df9 = df5.replace({"?":np.nan, "--":np.nan})
df9
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
df9.isnull().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %%
df9.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 34 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %% [markdown]
# Isi missing value pada kolom  children[10] dan country[13] dengan data yang paling banyak muncul.

# %%
df9.iloc[:, [10,13]]
# Out:
#         children country
# 0            0.0     PRT
# 1            0.0     PRT
# 2            0.0     GBR
# 3            0.0     GBR
# 4            0.0     GBR
# ...          ...     ...
# 119385       0.0     BEL
# 119386       0.0     FRA
# 119387       0.0     DEU
# 119388       0.0     GBR
# 119389       0.0     DEU
#
# [119390 rows x 2 columns]

# %% [markdown]
# Mengganti kolom agent [23] dengan mean

# %%
df9.iloc[:,23]=df9.iloc[:,23].fillna(df9.iloc[:,23].mean())

# %%
df9
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
df9.isnull().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %% [markdown]
# 6. Buat kategori berdasarkan lead time: Short, Medium, dan Long
# ### Jawaban no. 6:

# %%
df2=df

# %%
df2["leadtime_CAT"]=np.where(df2["lead_time"]>300, "Long_Trip",np.where(df2["lead_time"]>100, "Medium_Trip", "Short_trip"))
df2
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 34 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
df2.iloc[:,[2,33]]
# Out:
#         lead_time leadtime_CAT
# 0             342    Long_Trip
# 1             737    Long_Trip
# 2               7   Short_trip
# 3              13   Short_trip
# 4              14   Short_trip
# ...           ...          ...
# 119385         23   Short_trip
# 119386        102  Medium_Trip
# 119387         34   Short_trip
# 119388        109  Medium_Trip
# 119389        205  Medium_Trip
#
# [119390 rows x 2 columns]

# %% [markdown]
# 7. Filter semua data yang memiliki reservation_status_date di > 2017
# ### Jawaban No.7 :

# %%
df1 = df

# %%
df1["Reserved_CAT"] = np.where(df1["reservation_status_date"]>"2017-01-01", ">2017", "<2017")
df1
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 33 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
df1.iloc[:, [32]]
# Out:
#        Reserved_CAT
# 0             <2017
# 1             <2017
# 2             <2017
# 3             <2017
# 4             <2017
# ...             ...
# 119385        >2017
# 119386        >2017
# 119387        >2017
# 119388        >2017
# 119389        >2017
#
# [119390 rows x 1 columns]

# %%
filter1 = df1.loc[df1["Reserved_CAT"]==">2017"]
filter1
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 9788    Resort Hotel            1         89               2017
# 9805    Resort Hotel            1          6               2017
# 9809    Resort Hotel            1        112               2017
# 9818    Resort Hotel            1          2               2017
# 9838    Resort Hotel            1          0               2017
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 9788              January                         1
# 9805              January                         1
# ...

# %% [markdown]
# 8. Visualisasikan arrival_date_month untuk melihat bulan dimana pengunjung terbanyak

# %% [markdown]
# ### Jawaban No. 8

# %%
df8=df
df8
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
df8.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 34 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
df8.iloc[:, [4,9,10,11]]
# Out:
#        arrival_date_month  adults  children  babies
# 0                    July       2       0.0       0
# 1                    July       2       0.0       0
# 2                    July       1       0.0       0
# 3                    July       1       0.0       0
# 4                    July       2       0.0       0
# ...                   ...     ...       ...     ...
# 119385             August       2       0.0       0
# 119386             August       3       0.0       0
# 119387             August       2       0.0       0
# 119388             August       2       0.0       0
# 119389             August       2       0.0       0
#
# [119390 rows x 4 columns]

# %%
arrival_date_month = df8["arrival_date_month"]
adults = df8["adults"]

plt.bar(arrival_date_month , adults )

plt.title("visitor in month")
plt.xlabel("Month")
plt.ylabel("visitor")

plt.show()

# %%
arrival_date_month = df8["arrival_date_month"]
adults = df8["adults"]

plt.hist(arrival_date_month, bins =10, edgecolor="k", orientation = "horizontal")
plt.title("Total visitor in month")
plt.ylabel("Month")
plt.xlabel("Visitor")

plt.show()

# %%
plt.style.use("seaborn")

plt.scatter(df8["adults"], df8["arrival_date_month"], s=10)

plt.show()
